# %% [markdown]
# <a href="https://colab.research.google.com/github/Srinidhireddy25/AIML-2025/blob/main/lab_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ucimlrepo

# %%
from ucimlrepo import fetch_ucirepo
import numpy as np
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
# %matplotlib inline

#fetch dataset
power_con=fetch_ucirepo(id=235)
#data
X=power_con.data.features
Y=power_con.data.targets
# Out:
# /usr/local/lib/python3.10/dist-packages/ucimlrepo/fetch.py:97: DtypeWarning: Columns (2,3,4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(data_url)

# %%
type(power_con)
power_con.keys()
power_con.data.features.columns
print("Top 5 Power Consumption Results:\n")
power_con.data.features.head().sort_values(by='Voltage')
# Out:
# Top 5 Power Consumption Results:
#          Date      Time Global_active_power Global_reactive_power  Voltage  \
# 2  16/12/2006  17:26:00               5.374                 0.498  233.290
# 1  16/12/2006  17:25:00               5.360                 0.436  233.630
# 3  16/12/2006  17:27:00               5.388                 0.502  233.740
# 0  16/12/2006  17:24:00               4.216                 0.418  234.840
# 4  16/12/2006  17:28:00               3.666                 0.528  235.680
#
#   Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3
# 2           23.000          0.000          2.000            17.0
# 1           23.000          0.000          1.000            16.0
# 3           23.000          0.000          1.000            17.0
# 0           18.400          0.000          1.000            17.0
# 4           15.800          0.000          1.000            17.0

# %%
power_con.data.features.head().sort_values(by='data')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-fdbf7811dc47> in <cell line: 1>()
# ----> 1 power_con.data.features.head().sort_values(by='data')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7187             # len(by) == 1
#    7188
# -> 7189             k = self._get_label_or_level_values(by[0], axis=axis)
#    7190
#    7191             # need to rewrap column in Series to apply key function
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#
# KeyError: 'data'

# %%
power_con_df = DataFrame(power_con.data.features)
type(power_con_df)
# Out:
# pandas.core.frame.DataFrame
